# %% [markdown]
# ###The Beginning of the Data Pipeline

# %% [markdown]
# - Flow Control: Mastering the Waves
# - Python packages: writing your own functions and classes
# - Kimono Labs: an external tool for aquiring data

# %% [markdown]
# ##Flow Control: Catching your rhythm
# Using the keywords `for` and `while` create a loop that runs over an iterable data type (lists, dictionaries, etc.) or based on a condition, respectively.

# %%
a = [5,9,3,10,1,2,27]
for val in a:
    print val
# Out:
# 5
# 9
# 3
# 10
# 1
# 2
# 27

# %%
i = 0
while i < 5:
    i += 1
    print "iteration",i
# Out:
# iteration 1
# iteration 2
# iteration 3
# iteration 4
# iteration 5

# %%
for val in a:
    if val < 9:
        print val
    else:
        if val > 20:
            print "Way Too much!"
        else:
            print "Too Much"
# Out:
# 5
# Too Much
# 3
# Too Much
# 1
# 2
# Way Too much!

# %% [markdown]
# If/Else statements are great ways to insert logical checks or allow for alternatives

# %%
for i,val in enumerate(a):


    if i == 0:
        print i
    elif val < 4:
        print val
    else:
        continue
# Out:
# (0, 5)
# (1, 9)
# (2, 3)
# (3, 10)
# (4, 1)
# (5, 2)
# (6, 27)

# %% [markdown]
# Break breaks the loop

# %% [markdown]
# ##Python Packages and the Magic Within
# Python has a large number of packages, libraries, modules, functions, etc. and you'll hear these terms thrown around a lot. Here we'll define our vocabulary.

# %%
import numpy as np

# %% [markdown]
# Here, we are importing the package numpy. This allows us to reference modules underneath it. Modules are the text files that define functions and classes that can be referenced. Using the word `as` lets us give the numpy package a shortened alias. This is a common practice, but ultimately your choice. At large the python community tends to have standard aliases used (because programmers are lazy and that's a good thing).
#
# Note, some people refer to packages in python as "libraries". This is fine; don't judge them.
#
# Let's see what the documentation has to say about a specific function in np:

# %%
help(np.array)
# Out:
# Help on built-in function array in module numpy.core.multiarray:
#
# array(...)
#     array(object, dtype=None, copy=True, order=None, subok=False, ndmin=0)
#
#     Create an array.
#
#     Parameters
#     ----------
#     object : array_like
#         An array, any object exposing the array interface, an
#         object whose __array__ method returns an array, or any
#         (nested) sequence.
#     dtype : data-type, optional
#         The desired data-type for the array.  If not given, then
#         the type will be determined as the minimum type required
#         to hold the objects in the sequence.  This argument can only
#         be used to 'upcast' the array.  For downcasting, use the
#         .astype(t) method.
#     copy : bool, optional
#         If true (default), then the object is copied.  Otherwise, a copy
#         will only be made if __array__ returns a copy, if obj is a
#         nested sequence, or if a copy is needed to satisfy any of the other
#         requirements (`dtype`, `order`, etc.).
#     order : {'C', 'F', 'A'}, optional
#         Specify the order of the array.  If order is 'C' (default), then the
#         array will be in C-contiguous order (last-index varies the
#         fastest).  If order is 'F', then the returned array
#         will be in Fortran-contiguous order (first-index varies the
#         fastest).  If order is 'A', then the returned array may
#         be in any order (either C-, Fortran-contiguous, or even
#         discontiguous).
#     subok : bool, optional
#         If True, then sub-classes will be passed-through, otherwise
#         the returned array will be forced to be a base-class array (default).
#     ndmin : int, optional
#         Specifies the minimum number of dimensions that the resulting
#         array should have.  Ones will be pre-pended to the shape as
#         needed to meet this requirement.
#
#     Returns
#     -------
#     out : ndarray
#         An array object satisfying the specified requirements.
#
#     See Also
#     --------
#     empty, empty_like, zeros, zeros_like, ones, ones_like, fill
#
#     Examples
#     --------
#     >>> np.array([1, 2, 3])
#     array([1, 2, 3])
#
#     Upcasting:
#
#     >>> np.array([1, 2, 3.0])
#     array([ 1.,  2.,  3.])
#
#     More than one dimension:
#
#     >>> np.array([[1, 2], [3, 4]])
#     array([[1, 2],
#            [3, 4]])
#
#     Minimum dimensions 2:
#
#     >>> np.array([1, 2, 3], ndmin=2)
#     array([[1, 2, 3]])
#
#     Type provided:
#
#     >>> np.array([1, 2, 3], dtype=complex)
#     array([ 1.+0.j,  2.+0.j,  3.+0.j])
#
#     Data-type consisting of more than one element:
#
#     >>> x = np.array([(1,2),(3,4)],dtype=[('a','<i4'),('b','<i4')])
#     >>> x['a']
#     array([1, 3])
#
#     Creating an array from sub-classes:
#
#     >>> np.array(np.mat('1 2; 3 4'))
#     array([[1, 2],
#            [3, 4]])
#
#     >>> np.array(np.mat('1 2; 3 4'), subok=True)
#     matrix([[1, 2],
#             [3, 4]])

# %% [markdown]
# Note that this function is in a module titled numpy.core.multiarray. The periods reference namespacing, which is like referencing files within a directory.

# %% [markdown]
# ##Writing Functions and Classes: making your own tools

# %% [markdown]
# Functions are extremely important because they allow us to not repeat work, preserve code, and even serve as building blocks for more complex functions. We will explore the syntax here.

# %%
def square(x):
    
    return x*x

square(9)
# Out:
# 81

# %% [markdown]
# You can even put loops in your function

# %%
# 10! = 10*9*8*7*6*...*1

def factorial(x):
    start = 1
    for value in range(1,x+1):
        start = start*value
    return start

x = factorial(10)
print x
# Out:
# 3628800

# %% [markdown]
# ###Exercise 1.1
# Write a function that subtracts two values.

# %%
def subtract(x,y):
    result = x-y
    return result
subtract(10,20)
# Out:
# -10

# %%
print result
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-819e2eca8219> in <module>()
# ----> 1 print result
#
# NameError: name 'result' is not defined

# %% [markdown]
# But wait, you say. Those are related! And what if I want to recall the result and interact with a changing object? Well we'll group them in to a class called `calculator`
#
# BIG TAKEAWAY: Use a class for object oriented programming. If you have an object you want to preserve and modify with other functions, classes offer a truncated way to go about this.

# %%
class calculator():
    
    def __init__(self,x=0):
        self.result = x
    def square(self):
        val =self.result
        self.result = val*val
        return self.result
    
    def factorial(self):
        val = 1
        for n in range(2,self.result+1):
            val = val*n
        self.result = val
        return self.result
    
    def add(self,y):
        self.result += y
        return self.result

# %%
hermes = calculator(5)
hermes.add(10)
print hermes.result
hermes.square()
print hermes.result
hermes.add(3)
print "Hermes:",hermes.result

bob = calculator()
bob.add(5)
bob.factorial()
print "Bob:",bob.result
# Out:
# 15
# 225
# Hermes: 228
# Bob: 120

# %% [markdown]
# ###Bonus:
# Modify the class to add a inversion function (1 divided by itself)
# Demonstrate its use. Is the returned value correct (hint: think of numerical data types)

# %%
#On first pass, you may be tempted to try this, which is close:

class calculator():
    
    def __init__(self,x=0):
        self.result = x
    def square(self):
        val =self.result
        self.result = val*val
        return self.result
    
    def factorial(self):
        val = 1
        for n in range(2,self.result+1):
            val = val*n
        self.result = val
        return self.result
    
    def add(self,y):
        self.result += y
        return self.result

    def inversion(self):
        self.result = 1/self.result
        return self.result

# %%
twisty = calculator(20)
twisty.inversion()
print twisty.result
# Out:
# 0

# %% [markdown]
# Clearly that's incorrect. 1/20 is 0.05. Here, we need to make sure we have a float involved

# %%
class calculator():
    
    def __init__(self,x=0):
        self.result = x
    def square(self):
        val =self.result
        self.result = val*val
        return self.result
    
    def factorial(self):
        val = 1
        for n in range(2,self.result+1):
            val = val*n
        self.result = val
        return self.result
    
    def add(self,y):
        self.result += y
        return self.result

    def inversion(self):
        self.result = 1.0/float(self.result)
        return self.result

# %%
twisty = calculator(20)
twisty.inversion()
print twisty.result
# Out:
# 0.05

# %% [markdown]
# That's better!
#
# For more information, visit https://docs.python.org/2/tutorial/classes.html
#
# If you find yourself writing classes, please see me in office hours to learn about `__init__`

# %% [markdown]
# ## Kimono Labs

# %% [markdown]
# Web scraping with the Kimono Labs API
#
# https://www.kimonolabs.com/

# %%
from IPython.display import Image
Image(filename='KL_Crawl_Setup.png')

# %% [markdown]
# Change the crawl strategy to Generated URL List

# %%
from IPython.display import Image
Image(filename='KL_Generated_URL_List.png')

# %% [markdown]
# From here you can automatically generate a list of pages to extract data from, with the caveat that the pages you are navigating all have roughly the same structure. Here we are going to look for the top boxoffice_gross_us from 1990 to 2014.

# %%
from IPython.display import Image
Image(filename='KL_Parameter_range.png')

# %%
#After you let the data crawl the page, you can update the data here.

import json
import urllib

results = json.load(urllib.urlopen("https://www.kimonolabs.com/api/eb81bu78?apikey=4WrTjTsFDGmHCLnYrAXeSLIjJYcfrG7j"))
results
# Out:
# {u'count': 50,
#  u'frequency': u'Manual Crawl',
#  u'lastrunstatus': u'success',
#  u'name': u'IMDB Top Box Office by year',
#  u'newdata': True,
#  u'results': {u'collection1': [{u'description': u'A creature is intent on stealing Christmas.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/fantasy', u'text': u'Fantasy'}],
#     u'index': 1,
#     u'rating': u'6.0',
#     u'runtime': u'104 mins.',
#     u'sales': u'$260M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0170016/',
#      u'text': u'How the Grinch Stole Christmas'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A FedEx executive must transform himself physically and emotionally to survive a crash landing on a deserted island.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/adventure',
#       u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'}],
#     u'index': 2,
#     u'rating': u'7.7',
#     u'runtime': u'143 mins.',
#     u'sales': u'$234M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0162222/',
#      u'text': u'Cast Away'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A secret agent is sent to Sydney, to find and destroy a genetically modified disease called "Chimera"',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 3,
#     u'rating': u'6.0',
#     u'runtime': u'123 mins.',
#     u'sales': u'$215M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0120755/',
#      u'text': u'Mission: Impossible II'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"When a Roman general is betrayed and his family murdered by an emperor's corrupt son, he comes to Rome as a gladiator to seek revenge.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'}],
#     u'index': 4,
#     u'rating': u'8.5',
#     u'runtime': u'155 mins.',
#     u'sales': u'$188M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0172495/',
#      u'text': u'Gladiator'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"Male nurse Greg Focker meets his girlfriend's parents before proposing, but her suspicious father is every date's worst nightmare.",
#     u'genre': {u'href': u'http://www.imdb.com/genre/comedy',
#      u'text': u'Comedy'},
#     u'index': 5,
#     u'rating': u'7.0',
#     u'runtime': u'108 mins.',
#     u'sales': u'$166M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0212338/',
#      u'text': u'Meet the Parents'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A year after disposing the body of a man they accidently killed, a group of dumb teenagers are stalked by a bumbling serial killer.',
#     u'genre': {u'href': u'http://www.imdb.com/genre/comedy',
#      u'text': u'Comedy'},
#     u'index': 6,
#     u'rating': u'6.2',
#     u'runtime': u'88 mins.',
#     u'sales': u'$157M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0175142/',
#      u'text': u'Scary Movie'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'After an accident, a chauvenistic executive gains the ability to hear what women are really thinking.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/fantasy', u'text': u'Fantasy'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'},
#      {u'href': u'http://www.imdb.com/genre/sci_fi', u'text': u'Sci-Fi'}],
#     u'index': 7,
#     u'rating': u'6.4',
#     u'runtime': u'127 mins.',
#     u'sales': u'$183M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0207201/',
#      u'text': u'What Women Want'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An unusually intense storm pattern catches some commercial fishermen unaware and puts them in mortal danger.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 8,
#     u'rating': u'6.4',
#     u'runtime': u'130 mins.',
#     u'sales': u'$183M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0177971/',
#      u'text': u'The Perfect Storm'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Two mutants come to a private academy for their kind whose resident superhero team must oppose a terrorist organization with similar powers.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/sci_fi', u'text': u'Sci-Fi'}],
#     u'index': 9,
#     u'rating': u'7.4',
#     u'runtime': u'104 mins.',
#     u'sales': u'$157M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0120903/',
#      u'text': u'X-Men'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"An unemployed single mother becomes a legal assistant and almost single-handedly brings down a California power company accused of polluting a city's water supply.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/biography',
#       u'text': u'Biography'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'}],
#     u'index': 10,
#     u'rating': u'7.3',
#     u'runtime': u'131 mins.',
#     u'sales': u'$126M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0195685/',
#      u'text': u'Erin Brockovich'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'The wife of a university research scientist believes that her lakeside Vermont home is haunted by a ghost - or that she is losing her mind.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/drama',
#       u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/horror', u'text': u'Horror'},
#      {u'href': u'http://www.imdb.com/genre/mystery', u'text': u'Mystery'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 11,
#     u'rating': u'6.6',
#     u'runtime': u'130 mins.',
#     u'sales': u'$155M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0161081/',
#      u'text': u'What Lies Beneath'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"Two warriors in pursuit of a stolen sword and a notorious fugitive are led to an impetuous, physically skilled, adolescent nobleman's daughter, who is at a crossroads in her life.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'}],
#     u'index': 12,
#     u'rating': u'7.9',
#     u'runtime': u'120 mins.',
#     u'sales': u'$128M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0190332/',
#      u'text': u'Crouching Tiger, Hidden Dragon'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A nice-guy cop with dissociative identity disorder must protect a woman on the run from a corrupt ex-boyfriend and his associates.',
#     u'genre': {u'href': u'http://www.imdb.com/genre/comedy',
#      u'text': u'Comedy'},
#     u'index': 13,
#     u'rating': u'6.5',
#     u'runtime': u'116 mins.',
#     u'sales': u'$90.6M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0183505/',
#      u'text': u'Me, Myself & Irene'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An orphaned dinosaur raised by lemurs joins an arduous trek to a sancturary after a meteorite shower destroys his family home.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/animation',
#       u'text': u'Animation'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/sci_fi', u'text': u'Sci-Fi'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 14,
#     u'rating': u'6.4',
#     u'runtime': u'82 mins.',
#     u'sales': u'$138M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0130623/',
#      u'text': u'Dinosaur'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"A conservative judge is appointed by the President to spearhead America's escalating war against drugs, only to discover that his teenage daughter is an addict.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/crime',
#       u'text': u'Crime'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 15,
#     u'rating': u'7.7',
#     u'runtime': u'147 mins.',
#     u'sales': u'$124M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0181865/',
#      u'text': u'Traffic'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An FBI agent disguises himself as an old lady to protect a beautiful federal witness and her son.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'}],
#     u'index': 16,
#     u'rating': u'5.0',
#     u'runtime': u'99 mins.',
#     u'sales': u'$118M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0208003/',
#      u'text': u"Big Momma's House"},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'The true story of a newly appointed African-American coach and his high school team on their first season as a racially integrated unit.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/biography',
#       u'text': u'Biography'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/sport', u'text': u'Sport'}],
#     u'index': 17,
#     u'rating': u'7.8',
#     u'runtime': u'113 mins.',
#     u'sales': u'$116M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0210945/',
#      u'text': u'Remember the Titans'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Three women, detectives with a mysterious boss, retrieve stolen voice-ID software, using martial arts, tech skills, and sex appeal.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 18,
#     u'rating': u'5.5',
#     u'runtime': u'98 mins.',
#     u'sales': u'$125M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0160127/',
#      u'text': u"Charlie's Angels"},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Professor Sherman Klump is getting married. And the Klump family could not be more delighted for him...',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/fantasy', u'text': u'Fantasy'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'},
#      {u'href': u'http://www.imdb.com/genre/sci_fi', u'text': u'Sci-Fi'}],
#     u'index': 19,
#     u'rating': u'4.3',
#     u'runtime': u'106 mins.',
#     u'sales': u'$123M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0144528/',
#      u'text': u'Nutty Professor II: The Klumps'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Four friends take off on an 1800 mile road trip to retrieve an illicit tape mistakenly mailed to a girl friend.',
#     u'genre': {u'href': u'http://www.imdb.com/genre/comedy',
#      u'text': u'Comedy'},
#     u'index': 20,
#     u'rating': u'6.5',
#     u'runtime': u'93 mins.',
#     u'sales': u'$68.5M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0215129/',
#      u'text': u'Road Trip'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An FBI agent must go undercover in the Miss United States beauty pageant to prevent a group from bombing the event.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'}],
#     u'index': 21,
#     u'rating': u'6.1',
#     u'runtime': u'109 mins.',
#     u'sales': u'$107M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0212346/',
#      u'text': u'Miss Congeniality'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'When a bird "flies" into a chicken farm, the fellow chickens see him as an opportunity to escape their evil owners.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/animation',
#       u'text': u'Animation'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'}],
#     u'index': 22,
#     u'rating': u'7.1',
#     u'runtime': u'84 mins.',
#     u'sales': u'$107M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0120630/',
#      u'text': u'Chicken Run'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'While Sidney and her friends visit the Hollywood set of Stab 3, the third film based on the Woodsboro murders, a new Ghostface begins to terrorize them once again.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/horror',
#       u'text': u'Horror'},
#      {u'href': u'http://www.imdb.com/genre/mystery', u'text': u'Mystery'}],
#     u'index': 23,
#     u'rating': u'5.5',
#     u'runtime': u'116 mins.',
#     u'sales': u'$89.1M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0134084/',
#      u'text': u'Scream 3'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A German submarine is boarded by disguised American submariners trying to capture their Enigma cipher machine.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/war', u'text': u'War'}],
#     u'index': 24,
#     u'rating': u'6.6',
#     u'runtime': u'116 mins.',
#     u'sales': u'$77.1M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0141926/',
#      u'text': u'U-571'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"A retired master car thief must come back to the industry and steal 50 cars with his crew in one night to save his brother's life.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 25,
#     u'rating': u'6.5',
#     u'runtime': u'118 mins.',
#     u'sales': u'$102M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0187078/',
#      u'text': u'Gone in Sixty Seconds'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Peaceful farmer Benjamin Martin is driven to lead the Colonial Militia during the American Revolution when a sadistic British officer murders his son.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/history', u'text': u'History'},
#      {u'href': u'http://www.imdb.com/genre/war', u'text': u'War'}],
#     u'index': 26,
#     u'rating': u'7.1',
#     u'runtime': u'165 mins.',
#     u'sales': u'$113M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0187393/',
#      u'text': u'The Patriot'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Scientists discover how to make people invisible, but their test subject becomes an insane killer who stalks them.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/sci_fi',
#       u'text': u'Sci-Fi'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 27,
#     u'rating': u'5.7',
#     u'runtime': u'112 mins.',
#     u'sales': u'$73.2M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0164052/',
#      u'text': u'Hollow Man'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'When a retired engineer is called upon to rescue a failing satellite, he insists that his equally old teammates accompany him into space.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 28,
#     u'rating': u'6.4',
#     u'runtime': u'130 mins.',
#     u'sales': u'$90.5M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0186566/',
#      u'text': u'Space Cowboys'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A woman and her daughter open a chocolate shop in a small French village that shakes up the rigid morality of the community.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/drama',
#       u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'}],
#     u'index': 29,
#     u'rating': u'7.3',
#     u'runtime': u'121 mins.',
#     u'sales': u'$71.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0241303/',
#      u'text': u'Chocolat'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"Uncle Elroy and Day Day owe money on taxes so Craig finds a way to steal from the next door neighbors to pay off the taxes so Uncle Elroy's house doesn't get put up for auction.",
#     u'genre': {u'href': u'http://www.imdb.com/genre/comedy',
#      u'text': u'Comedy'},
#     u'index': 30,
#     u'rating': u'6.0',
#     u'runtime': u'98 mins.',
#     u'sales': u'$57.2M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0195945/',
#      u'text': u'Next Friday'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A young writing prodigy finds a mentor in a reclusive author.',
#     u'genre': {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#     u'index': 31,
#     u'rating': u'7.3',
#     u'runtime': u'136 mins.',
#     u'sales': u'$51.8M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0181536/',
#      u'text': u'Finding Forrester'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A man learns something extraordinary about himself after a devastating accident.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/drama',
#       u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/mystery', u'text': u'Mystery'},
#      {u'href': u'http://www.imdb.com/genre/sci_fi', u'text': u'Sci-Fi'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 32,
#     u'rating': u'7.2',
#     u'runtime': u'106 mins.',
#     u'sales': u'$95M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0217869/',
#      u'text': u'Unbreakable'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"A champion high school cheerleading squad discovers its previous captain stole all their best routines from an inner-city school and must scramble to compete at this year's championships.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/sport', u'text': u'Sport'}],
#     u'index': 33,
#     u'rating': u'5.9',
#     u'runtime': u'98 mins.',
#     u'sales': u'$68.4M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0204946/',
#      u'text': u'Bring It On'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An FBI agent persuades a social worker, who is adept with a new experimental technology, to enter the mind of a comatose serial killer in order to learn where he has hidden his latest kidnap victim.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/sci_fi',
#       u'text': u'Sci-Fi'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 34,
#     u'rating': u'6.3',
#     u'runtime': u'107 mins.',
#     u'sales': u'$61.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0209958/',
#      u'text': u'The Cell'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'New York City police detective John Shaft (nephew of the original 1970s detective) goes on a personal mission to make sure the son of a real estate tycoon is brought to justice after a racially-motivated murder.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 35,
#     u'rating': u'5.9',
#     u'runtime': u'99 mins.',
#     u'sales': u'$70.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0162650/',
#      u'text': u'Shaft'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An unhappy and disliked image consultant gets a second shot at life when an eight year old version of himself mysteriously appears.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/fantasy', u'text': u'Fantasy'}],
#     u'index': 36,
#     u'rating': u'6.0',
#     u'runtime': u'104 mins.',
#     u'sales': u'$69.7M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0219854/',
#      u'text': u'The Kid'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Nick is a struggling dentist in Canada. A new neighbor moves in, and he discovers that it is Jimmy "The Tulip" Teduski. His wife convinces him to go to Chicago and inform the mob boss who wants Jimmy dead.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'}],
#     u'index': 37,
#     u'rating': u'6.7',
#     u'runtime': u'98 mins.',
#     u'sales': u'$57.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0190138/',
#      u'text': u'The Whole Nine Yards'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A fast-lane investment broker, offered the opportunity to see how the other half lives, wakes up to find that his sports car and girlfriend have become a mini-van and wife.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/fantasy', u'text': u'Fantasy'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'}],
#     u'index': 38,
#     u'rating': u'6.7',
#     u'runtime': u'125 mins.',
#     u'sales': u'$75.8M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0218967/',
#      u'text': u'The Family Man'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'After a teenager has a terrifying vision of him and his friends dying in a plane crash, he prevents the accident only to have Death hunt them down, one by one.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/horror',
#       u'text': u'Horror'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 39,
#     u'rating': u'6.7',
#     u'runtime': u'98 mins.',
#     u'sales': u'$53.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0195714/',
#      u'text': u'Final Destination'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Emperor Kuzco is turned into a llama by his ex-administrator Yzma, and must now regain his throne with the help of Pacha, the gentle llama herder.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/animation',
#       u'text': u'Animation'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/fantasy', u'text': u'Fantasy'}],
#     u'index': 40,
#     u'rating': u'7.3',
#     u'runtime': u'78 mins.',
#     u'sales': u'$89.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0120917/',
#      u'text': u"The Emperor's New Groove"},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Cruella DeVil gets out of prison and goes after them darned puppies once more.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/adventure',
#       u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'}],
#     u'index': 41,
#     u'rating': u'4.8',
#     u'runtime': u'100 mins.',
#     u'sales': u'$66.9M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0211181/',
#      u'text': u'102 Dalmatians'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'An attorney defends an officer on trial for ordering his troops to fire on civilians after they stormed a U.S. embassy in a third world country.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/war', u'text': u'War'}],
#     u'index': 42,
#     u'rating': u'6.3',
#     u'runtime': u'128 mins.',
#     u'sales': u'$61.3M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0160797/',
#      u'text': u'Rules of Engagement'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'The Rugrats travel to Paris, France, where Chuckie hopes to find a new mother and keep his father from marrying an evil business woman.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/animation',
#       u'text': u'Animation'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'}],
#     u'index': 43,
#     u'rating': u'6.1',
#     u'runtime': u'78 mins.',
#     u'sales': u'$76.5M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0213203/',
#      u'text': u'Rugrats in Paris: The Movie'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'When a school in upstate New York is snowed in, a group of students hi-jack a plow to keep the school closed.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/adventure',
#       u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'}],
#     u'index': 44,
#     u'rating': u'4.9',
#     u'runtime': u'89 mins.',
#     u'sales': u'$60M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0184907/',
#      u'text': u'Snow Day'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"A climber must rescue his sister on top of K2, one of the world's biggest mountains.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 45,
#     u'rating': u'5.8',
#     u'runtime': u'124 mins.',
#     u'sales': u'$68.5M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0190865/',
#      u'text': u'Vertical Limit'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u"An avenging cop seeks out his brother's killer and falls for the daughter of a businessman who is involved in a money-deal with his father.",
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/crime', u'text': u'Crime'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 46,
#     u'rating': u'6.1',
#     u'runtime': u'115 mins.',
#     u'sales': u'$56M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0165929/',
#      u'text': u'Romeo Must Die'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'When the first manned mission to Mars meets with a catastrophic and mysterious disaster after reporting a unidentified structure, a rescue mission is launched to investigate the tragedy and bring back any survivors.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/adventure',
#       u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/sci_fi', u'text': u'Sci-Fi'},
#      {u'href': u'http://www.imdb.com/genre/thriller', u'text': u'Thriller'}],
#     u'index': 47,
#     u'rating': u'5.5',
#     u'runtime': u'114 mins.',
#     u'sales': u'$60.9M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0183523/',
#      u'text': u'Mission to Mars'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Aspiring songwriter Violet Sanford, after getting a job at a women-run NYC bar that teases its male patrons, comes out of her shell.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/comedy',
#       u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/drama', u'text': u'Drama'},
#      {u'href': u'http://www.imdb.com/genre/music', u'text': u'Music'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'}],
#     u'index': 48,
#     u'rating': u'5.6',
#     u'runtime': u'100 mins.',
#     u'sales': u'$60.8M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0200550/',
#      u'text': u'Coyote Ugly'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'A Chinese man who travels to the Wild West to rescue a kidnapped princess. After teaming up with a train robber, the unlikely duo takes on a Chinese traitor and his corrupt boss.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/action',
#       u'text': u'Action'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/western', u'text': u'Western'}],
#     u'index': 49,
#     u'rating': u'6.6',
#     u'runtime': u'110 mins.',
#     u'sales': u'$56.9M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0184894/',
#      u'text': u'Shanghai Noon'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'},
#    {u'description': u'Two swindlers get their hands on a map to the fabled city of gold, El Dorado.',
#     u'genre': [{u'href': u'http://www.imdb.com/genre/animation',
#       u'text': u'Animation'},
#      {u'href': u'http://www.imdb.com/genre/adventure', u'text': u'Adventure'},
#      {u'href': u'http://www.imdb.com/genre/comedy', u'text': u'Comedy'},
#      {u'href': u'http://www.imdb.com/genre/family', u'text': u'Family'},
#      {u'href': u'http://www.imdb.com/genre/romance', u'text': u'Romance'}],
#     u'index': 50,
#     u'rating': u'6.9',
#     u'runtime': u'89 mins.',
#     u'sales': u'$50.8M',
#     u'title': {u'href': u'http://www.imdb.com/title/tt0138749/',
#      u'text': u'The Road to El Dorado'},
#     u'url': u'http://www.imdb.com/search/title?at=0&sort=boxoffice_gross_us&title_type=feature&year=2000,2000'}]},
#  u'thisversionrun': u'Tue Aug 04 2015 17:42:05 GMT+0000 (UTC)',
#  u'thisversionstatus': u'success',
#  u'version': 3}

# %%
your_key = "4WrTjTsFDGmHCLnYrAXeSLIjJYcfrG7j"
your_endpoint = "eb81bu78"
import json
import urllib
import pandas as pd

def getMovies(api_key=your_key,endpoint=your_endpoint):
    """
    Creates list of top 50 movies by gross box office
    sales for a with ratings and sales
    """
    
    movies, ratings, sales, years = [], [], [], []
    #Remember to replace this link with the link to your specifc API
    url = "https://www.kimonolabs.com/api/{}?".format(endpoint) + \
            "apikey={}".format(api_key)
    
    data = json.load(urllib.urlopen(url))
    
    # Iterate through json object to collect data
    for n in xrange(data['count']):
        n_title = data['results']['collection1'][n]['title']['text']
        n_rating = float(data['results']['collection1'][n]['rating'])
        n_sales = float(data['results']['collection1'][n]['sales'][1:-1])
        n_year = int(data['results']['collection1'][n]['url'][-4:])
        movies.append(n_title)
        ratings.append(n_rating)
        sales.append(n_sales)
        years.append(n_year)
    data = pd.DataFrame({'movie':movies,'rating':ratings,'sales_in_M':sales,'year':years})
    
    return data
movies = getMovies()
movies.head()
# Out:
#                 movie  rating  sales_in_M  year
# 0          Home Alone     7.4         286  1990
# 1               Ghost     7.0         218  1990
# 2  Dances with Wolves     8.0         184  1990
# 3        Pretty Woman     6.9         178  1990
# 4        Total Recall     7.5         119  1990

# %% [markdown]
# Note a few things: The function we wrote relies on extracting pieces of a string and converting them to numeric types. Here, the year can be extracted from the url used to generate the movies, so we use the slice `[-4:]` to identify that. Similarly, the gross cost comes out as $##M, so we know we never want the first or last value. Thus the slice `[1:-1]` is correct.

# %% [markdown]
# ###Exercise 2.1
# Build your own api via kimono at https://www.kimonolabs.com/. Create the api we created in class to call the data.
#
# What were the average sales in 1995?
# What was the average rating?

# %%
print "Avg Sales:",movies.sales_in_M[movies.year == 1995].mean(),"Million"
print "Avg Rating:",movies.rating[movies.year == 1995].mean()
# Out:
# Avg Sales: 67.212 Million
# Avg Rating: 6.504

# %% [markdown]
# ###Bonus
# What were the average sales for the 90s? How does that differ from the 2000s?

# %%
nineties_s = movies.sales_in_M[(1990 <= movies.year)&(movies.year < 2000)].mean()
two_thou_s = movies.sales_in_M[(2000 <= movies.year)&(movies.year < 2010)].mean()
print "Avg 90's Sales:",nineties_s,"Million"
print "Avg 2000's Sales:",two_thou_s,"Million"
print "Diff = ",two_thou_s-nineties_s,"Million"
# Out:
# Avg 90's Sales: 78.6918 Million
# Avg 2000's Sales: 123.3746 Million
# Diff =  44.6828 Million
